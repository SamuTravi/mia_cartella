# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

import numpy

def GenerateTrainTestSet(titanic, Fs, F2, threshold=1000):
    sub = titanic[titanic.PassengerId < threshold]
    x_train, x_test, y_train, y_test = train_test_split(sub[Fs], sub[F2], random_state=0)
    return x_train, x_test, y_train, y_test


def eta(x):
    if (numpy.isnan(x)):
        return (0)
    try:
        return float(x)
    except:
        return float(0)
    
    
def Train(titanic): 
    def ConvertInput(data):
        data['Sex'] = data['Sex'].apply(lambda x: int(x == 'male'))       
        data['Age'] = data['Age'].apply(eta)
        return data
    
    def Predict(X):
        try:
            X = ConvertInput(X)
            y_pred = logit.predict_proba(X[['Pclass','Sex','Age']])
            y_pred = [1 if p[0] < p[1] else 0 for p in y_pred]
            return y_pred
        except:
            return list(map(lambda x: 0, X))
    
    titanic = ConvertInput(titanic)
    x_train, x_test, y_train, y_test = GenerateTrainTestSet(titanic, ['Pclass','Sex','Age'], 'Survived')

    # In questo caso ho ignorato il training set
    logit = LogisticRegression(penalty='l2', class_weight='balanced')
    # Input to this function must be "DataFrames"
    logit.fit(x_train, y_train)
            
    return Predict

# %%
 from sklearn.linear_model import LogisticRegression               ############ lo provo e lo studio ####### boh
from sklearn.model_selection import train_test_split

import numpy

def GenerateTrainTestSet(titanic, Fs, F2, threshold=1000):
    sub = titanic[titanic.PassengerId < threshold]
    x_train, x_test, y_train, y_test = train_test_split(sub[Fs], sub[F2], random_state=0)
    return x_train, x_test, y_train, y_test


def eta(x):
    if (numpy.isnan(x)):
        return (0)
    try:
        return float(x)
    except:
        return float(0)
    
    
def Train(titanic): 
    def ConvertInput(data):
        data['Sex'] = data['Sex'].apply(lambda x: int(x == 'male'))       
        data['Age'] = data['Age'].apply(eta)
        return data
    
    def Predict(X):
        try:
            X = ConvertInput(X)
            y_pred = logit.predict_proba(X[['Pclass','Sex','Age']])
            y_pred = [1 if p[0] < p[1] else 0 for p in y_pred]
            return y_pred
        except:
            return list(map(lambda x: 0, X))
    
    titanic = ConvertInput(titanic)
    x_train, x_test, y_train, y_test = GenerateTrainTestSet(titanic, ['Pclass','Sex','Age'], 'Survived')

    # In questo caso ho ignorato il training set
    logit = LogisticRegression(penalty='l2', class_weight='balanced')
    # Input to this function must be "DataFrames"
    logit.fit(x_train, y_train)
            
    return Predict

import pandas as pd
import seaborn as sns

tit=pd.read_csv('train.csv')
Train(tit)
sns.jointplot(data=tit, x='Sex', y='Age', kind='reg', color='g')
sns.plt.show()
# Out:
# C:\Users\Utente\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
